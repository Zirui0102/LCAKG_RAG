# %% [markdown]
# **LCA modeling result**

# %%
import re
import pandas as pd
from bert_score import score

# %%
def clean_text(s):
    """Normalize a string by lowercasing, trimming whitespace, and standardizing separators."""
    s = str(s)
    s = s.lower().strip()
    # replace all dash-like characters with space
    s = re.sub(r"[-–—-]", " ", s)    # covers -, –, —, and non-breaking hyphen
    s = re.sub(r"\s+", " ", s)       # collapse multiple spaces
    return s

def normalize_LCIAMethod_text(text):
    """Normalize LCIA method names by separating alphanumeric tokens."""
    text = re.sub(r"(\D)(\d)", r"\1 \2", text)  # split letter-number
    text = re.sub(r"(\d)(\D)", r"\1 \2", text)  # split number-letter
    text = re.sub(r"\s+", " ", text).strip()
    return text

# %%
file_path = "Result_calculation_LCA_modeling.xlsx"   # replace with actual path

df_pred = pd.read_excel(file_path, sheet_name='Pred')
df_ref = pd.read_excel(file_path, sheet_name='Reference')

# %% [markdown]
# **1. System boundary**

# %%
preds = df_pred["System boundary"].fillna("").map(clean_text).tolist()
refs  = df_ref["System boundary"].fillna("").map(clean_text).tolist()

# %%
# Compute BERTScore across rows
P, R, F1 = score(preds, refs, lang="en-sci", rescale_with_baseline=True)

# Print per-row precision, recall, and F1
print("=== Row-level BERTScores ===")
for i, (p, r, f) in enumerate(zip(P, R, F1), start=1):
    print(f"Row {i}: Precision = {p:.3f}, Recall = {r:.3f}, F1 = {f:.3f}")

# Print averages across all rows
print("\n=== Average BERTScores ===")
print(f"Average Precision: {P.mean():.4f}")
print(f"Average Recall:    {R.mean():.4f}")
print(f"Average F1:        {F1.mean():.4f}")
# Out:
# C:\Software\Anaconda\envs\LangChain\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# === Row-level BERTScores ===
# Row 1: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 2: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 3: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 4: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 5: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 6: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 7: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 8: Precision = 0.147, Recall = 0.079, F1 = 0.114
# Row 9: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 10: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 11: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 12: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 13: Precision = 0.380, Recall = 0.299, F1 = 0.340
# Row 14: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 15: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 16: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 17: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 18: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 19: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 20: Precision = 0.148, Recall = 0.101, F1 = 0.127
# Row 21: Precision = 0.687, Recall = 0.563, F1 = 0.624
# Row 22: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 23: Precision = 0.148, Recall = 0.101, F1 = 0.127
# Row 24: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 25: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 26: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 27: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 28: Precision = 0.148, Recall = 0.101, F1 = 0.127
# Row 29: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 30: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 31: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 32: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 33: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 34: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 35: Precision = 0.067, Recall = 0.010, F1 = 0.041
# Row 36: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 37: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 38: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 39: Precision = 0.148, Recall = 0.101, F1 = 0.127
# Row 40: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 41: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 42: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 43: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 44: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 45: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 46: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 47: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 48: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 49: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 50: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 51: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 52: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 53: Precision = 0.148, Recall = 0.101, F1 = 0.127
# Row 54: Precision = 0.148, Recall = 0.101, F1 = 0.127
# Row 55: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 56: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 57: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 58: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 59: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 60: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 61: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 62: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 63: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 64: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 65: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 66: Precision = 1.000, Recall = 1.000, F1 = 1.000
#
# === Average BERTScores ===
# Average Precision: 0.8814
# Average Recall:    0.8720
# Average F1:        0.8770

# %% [markdown]
# **2. Functional unit**

# %%
preds = df_pred["Functional unit"].fillna("").map(clean_text).tolist()
refs  = df_ref["Functional unit"].fillna("").map(clean_text).tolist()

# %%
# Compute BERTScore across rows
P, R, F1 = score(preds, refs, lang="en-sci", rescale_with_baseline=True)

# Print per-row precision, recall, and F1
print("=== Row-level BERTScores ===")
for i, (p, r, f) in enumerate(zip(P, R, F1), start=1):
    print(f"Row {i}: Precision = {p:.3f}, Recall = {r:.3f}, F1 = {f:.3f}")

# Print averages across all rows
print("\n=== Average BERTScores ===")
print(f"Average Precision: {P.mean():.4f}")
print(f"Average Recall:    {R.mean():.4f}")
print(f"Average F1:        {F1.mean():.4f}")
# Out:
# C:\Software\Anaconda\envs\LangChain\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# === Row-level BERTScores ===
# Row 1: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 2: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 3: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 4: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 5: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 6: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 7: Precision = 0.926, Recall = 0.834, F1 = 0.879
# Row 8: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 9: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 10: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 11: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 12: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 13: Precision = 0.126, Recall = -0.128, F1 = -0.012
# Row 14: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 15: Precision = 0.635, Recall = 0.436, F1 = 0.531
# Row 16: Precision = 0.463, Recall = 0.543, F1 = 0.504
# Row 17: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 18: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 19: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 20: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 21: Precision = 0.852, Recall = 0.568, F1 = 0.700
# Row 22: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 23: Precision = 0.640, Recall = 0.386, F1 = 0.504
# Row 24: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 25: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 26: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 27: Precision = 0.355, Recall = 0.102, F1 = 0.219
# Row 28: Precision = 0.043, Recall = 0.103, F1 = 0.075
# Row 29: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 30: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 31: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 32: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 33: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 34: Precision = 0.026, Recall = 0.415, F1 = 0.195
# Row 35: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 36: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 37: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 38: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 39: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 40: Precision = 0.866, Recall = 0.710, F1 = 0.785
# Row 41: Precision = 0.600, Recall = 0.388, F1 = 0.489
# Row 42: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 43: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 44: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 45: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 46: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 47: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 48: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 49: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 50: Precision = 0.757, Recall = 0.541, F1 = 0.644
# Row 51: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 52: Precision = 0.669, Recall = 0.327, F1 = 0.482
# Row 53: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 54: Precision = 0.116, Recall = -0.024, F1 = 0.045
# Row 55: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 56: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 57: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 58: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 59: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 60: Precision = 0.394, Recall = 0.064, F1 = 0.212
# Row 61: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 62: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 63: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 64: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 65: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 66: Precision = 1.000, Recall = 1.000, F1 = 1.000
#
# === Average BERTScores ===
# Average Precision: 0.8859
# Average Recall:    0.8525
# Average F1:        0.8675

# %% [markdown]
# **3. Impact Assessment method**

# %%
preds = df_pred["Impact assessment method"].fillna("").map(clean_text).tolist()
refs  = df_ref["Impact assessment method"].fillna("").map(clean_text).tolist()

# %%
refs = [normalize_LCIAMethod_text(r) for r in refs]
preds = [normalize_LCIAMethod_text(p) for p in preds]

# %%
# Compute BERTScore across rows
P, R, F1 = score(preds, refs, lang="en-sci", rescale_with_baseline=True)

# Print per-row precision, recall, and F1
print("=== Row-level BERTScores ===")
for i, (p, r, f) in enumerate(zip(P, R, F1), start=1):
    print(f"Row {i}: Precision = {p:.3f}, Recall = {r:.3f}, F1 = {f:.3f}")

# Print averages across all rows
print("\n=== Average BERTScores ===")
print(f"Average Precision: {P.mean():.4f}")
print(f"Average Recall:    {R.mean():.4f}")
print(f"Average F1:        {F1.mean():.4f}")
# Out:
# C:\Software\Anaconda\envs\LangChain\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# === Row-level BERTScores ===
# Row 1: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 2: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 3: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 4: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 5: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 6: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 7: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 8: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 9: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 10: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 11: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 12: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 13: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 14: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 15: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 16: Precision = 0.441, Recall = 0.441, F1 = 0.443
# Row 17: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 18: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 19: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 20: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 21: Precision = 0.265, Recall = 0.644, F1 = 0.433
# Row 22: Precision = 0.872, Recall = 0.667, F1 = 0.765
# Row 23: Precision = 0.359, Recall = 0.550, F1 = 0.450
# Row 24: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 25: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 26: Precision = 0.167, Recall = 0.158, F1 = 0.165
# Row 27: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 28: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 29: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 30: Precision = 0.167, Recall = 0.158, F1 = 0.165
# Row 31: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 32: Precision = 0.419, Recall = 0.256, F1 = 0.335
# Row 33: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 34: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 35: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 36: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 37: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 38: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 39: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 40: Precision = 0.584, Recall = 0.835, F1 = 0.702
# Row 41: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 42: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 43: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 44: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 45: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 46: Precision = 0.015, Recall = 0.095, F1 = 0.056
# Row 47: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 48: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 49: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 50: Precision = 0.049, Recall = 0.127, F1 = 0.089
# Row 51: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 52: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 53: Precision = 0.529, Recall = 0.434, F1 = 0.481
# Row 54: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 55: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 56: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 57: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 58: Precision = 0.482, Recall = 0.555, F1 = 0.519
# Row 59: Precision = 0.717, Recall = 0.466, F1 = 0.584
# Row 60: Precision = 0.698, Recall = 0.275, F1 = 0.461
# Row 61: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 62: Precision = 0.141, Recall = 0.106, F1 = 0.126
# Row 63: Precision = 0.547, Recall = 0.787, F1 = 0.660
# Row 64: Precision = 0.415, Recall = 0.786, F1 = 0.582
# Row 65: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 66: Precision = 1.000, Recall = 1.000, F1 = 1.000
#
# === Average BERTScores ===
# Average Precision: 0.8465
# Average Recall:    0.8537
# Average F1:        0.8487

# %% [markdown]
# **4. Impact category**

# %%
preds = df_pred["Impact category"].fillna("").map(clean_text).tolist()
refs  = df_ref["Impact category"].fillna("").map(clean_text).tolist()

# %%
# Compute BERTScore across rows
P, R, F1 = score(preds, refs, lang="en-sci", rescale_with_baseline=True)

# Print per-row precision, recall, and F1
print("=== Row-level BERTScores ===")
for i, (p, r, f) in enumerate(zip(P, R, F1), start=1):
    print(f"Row {i}: Precision = {p:.3f}, Recall = {r:.3f}, F1 = {f:.3f}")

# Print averages across all rows
print("\n=== Average BERTScores ===")
print(f"Average Precision: {P.mean():.4f}")
print(f"Average Recall:    {R.mean():.4f}")
print(f"Average F1:        {F1.mean():.4f}")
# Out:
# C:\Software\Anaconda\envs\LangChain\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# === Row-level BERTScores ===
# Row 1: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 2: Precision = 0.884, Recall = 0.961, F1 = 0.922
# Row 3: Precision = 0.969, Recall = 0.955, F1 = 0.962
# Row 4: Precision = 0.991, Recall = 0.989, F1 = 0.990
# Row 5: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 6: Precision = 0.824, Recall = 0.912, F1 = 0.868
# Row 7: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 8: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 9: Precision = 0.885, Recall = 0.838, F1 = 0.862
# Row 10: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 11: Precision = 0.638, Recall = 0.699, F1 = 0.669
# Row 12: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 13: Precision = 0.507, Recall = 0.594, F1 = 0.551
# Row 14: Precision = 0.843, Recall = 0.846, F1 = 0.845
# Row 15: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 16: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 17: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 18: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 19: Precision = 0.925, Recall = 0.903, F1 = 0.914
# Row 20: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 21: Precision = 0.871, Recall = 0.620, F1 = 0.738
# Row 22: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 23: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 24: Precision = 0.853, Recall = 0.919, F1 = 0.886
# Row 25: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 26: Precision = 0.851, Recall = 0.612, F1 = 0.724
# Row 27: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 28: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 29: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 30: Precision = 0.851, Recall = 0.612, F1 = 0.724
# Row 31: Precision = 0.851, Recall = 0.612, F1 = 0.724
# Row 32: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 33: Precision = 0.980, Recall = 0.973, F1 = 0.976
# Row 34: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 35: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 36: Precision = 0.034, Recall = 0.338, F1 = 0.171
# Row 37: Precision = 0.960, Recall = 0.832, F1 = 0.894
# Row 38: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 39: Precision = 0.765, Recall = 0.707, F1 = 0.736
# Row 40: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 41: Precision = 0.918, Recall = 0.859, F1 = 0.888
# Row 42: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 43: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 44: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 45: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 46: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 47: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 48: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 49: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 50: Precision = 0.909, Recall = 0.884, F1 = 0.896
# Row 51: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 52: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 53: Precision = 0.427, Recall = 0.243, F1 = 0.331
# Row 54: Precision = 0.867, Recall = 0.706, F1 = 0.783
# Row 55: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 56: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 57: Precision = 0.919, Recall = 0.910, F1 = 0.915
# Row 58: Precision = 0.830, Recall = 0.806, F1 = 0.818
# Row 59: Precision = 0.913, Recall = 0.874, F1 = 0.893
# Row 60: Precision = 0.961, Recall = 0.960, F1 = 0.960
# Row 61: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 62: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 63: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 64: Precision = 0.738, Recall = 0.386, F1 = 0.545
# Row 65: Precision = 0.942, Recall = 0.942, F1 = 0.943
# Row 66: Precision = 0.676, Recall = 0.459, F1 = 0.562
#
# === Average BERTScores ===
# Average Precision: 0.9179
# Average Recall:    0.8932
# Average F1:        0.9045

# %% [markdown]
# **5. Geography**

# %%
preds = df_pred["Geography"].fillna("").map(clean_text).tolist()
refs  = df_ref["Geography"].fillna("").map(clean_text).tolist()

# Compute BERTScore across rows
P, R, F1 = score(preds, refs, lang="en-sci", rescale_with_baseline=True)

print("=== Row-level BERTScores ===")
for i, (p, r, f) in enumerate(zip(P, R, F1), start=1):
    print(f"Row {i}: Precision = {p:.3f}, Recall = {r:.3f}, F1 = {f:.3f}")

# Print averages across all rows
print("\n=== Average BERTScores ===")
print(f"Average Precision: {P.mean():.4f}")
print(f"Average Recall:    {R.mean():.4f}")
print(f"Average F1:        {F1.mean():.4f}")
# Out:
# C:\Software\Anaconda\envs\LangChain\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# === Row-level BERTScores ===
# Row 1: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 2: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 3: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 4: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 5: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 6: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 7: Precision = 0.225, Recall = 0.113, F1 = 0.169
# Row 8: Precision = 0.312, Recall = 0.199, F1 = 0.256
# Row 9: Precision = 0.151, Recall = 0.151, F1 = 0.153
# Row 10: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 11: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 12: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 13: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 14: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 15: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 16: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 17: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 18: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 19: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 20: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 21: Precision = 0.082, Recall = -0.277, F1 = -0.125
# Row 22: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 23: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 24: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 25: Precision = 0.151, Recall = 0.151, F1 = 0.153
# Row 26: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 27: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 28: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 29: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 30: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 31: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 32: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 33: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 34: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 35: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 36: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 37: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 38: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 39: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 40: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 41: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 42: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 43: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 44: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 45: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 46: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 47: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 48: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 49: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 50: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 51: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 52: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 53: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 54: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 55: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 56: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 57: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 58: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 59: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 60: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 61: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 62: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 63: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 64: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 65: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 66: Precision = 1.000, Recall = 1.000, F1 = 1.000
#
# === Average BERTScores ===
# Average Precision: 0.9382
# Average Recall:    0.9293
# Average F1:        0.9334

# %% [markdown]
# **LCIA result**

# %%
file_path = "Result_calculation_LCAResult.xlsx"   # replace with actual path
df_pred = pd.read_excel(file_path, sheet_name='Pred')
df_ref = pd.read_excel(file_path, sheet_name='Reference')

# %%
preds = df_pred["LCIA results"].fillna("").map(clean_text).tolist()
refs  = df_ref["LCIA results"].fillna("").map(clean_text).tolist()

# %%
len(preds), len(refs)
# Out:
# (52, 52)

# %%
# Compute BERTScore across rows
P, R, F1 = score(preds, refs, lang="en-sci", rescale_with_baseline=True)

# Print per-row precision, recall, and F1
print("=== Row-level BERTScores ===")
for i, (p, r, f) in enumerate(zip(P, R, F1), start=1):
    print(f"Row {i}: Precision = {p:.3f}, Recall = {r:.3f}, F1 = {f:.3f}")

# Print averages across all rows
print("\n=== Average BERTScores ===")
print(f"Average Precision: {P.mean():.4f}")
print(f"Average Recall:    {R.mean():.4f}")
print(f"Average F1:        {F1.mean():.4f}")
# Out:
# C:\Software\Anaconda\envs\LangChain\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# === Row-level BERTScores ===
# Row 1: Precision = 0.909, Recall = 0.954, F1 = 0.932
# Row 2: Precision = 0.760, Recall = 0.668, F1 = 0.713
# Row 3: Precision = 0.815, Recall = 0.850, F1 = 0.832
# Row 4: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 5: Precision = 0.764, Recall = 0.601, F1 = 0.680
# Row 6: Precision = 0.982, Recall = 0.982, F1 = 0.982
# Row 7: Precision = 0.928, Recall = 0.831, F1 = 0.879
# Row 8: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 9: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 10: Precision = 0.938, Recall = 0.879, F1 = 0.908
# Row 11: Precision = 0.753, Recall = 0.652, F1 = 0.702
# Row 12: Precision = 0.226, Recall = -0.182, F1 = -0.011
# Row 13: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 14: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 15: Precision = 0.370, Recall = 0.388, F1 = 0.381
# Row 16: Precision = 0.779, Recall = 0.766, F1 = 0.773
# Row 17: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 18: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 19: Precision = -0.046, Recall = 0.078, F1 = 0.015
# Row 20: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 21: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 22: Precision = -0.053, Recall = 0.128, F1 = 0.034
# Row 23: Precision = 0.371, Recall = 0.185, F1 = 0.274
# Row 24: Precision = 0.521, Recall = 0.424, F1 = 0.472
# Row 25: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 26: Precision = 0.921, Recall = 0.961, F1 = 0.941
# Row 27: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 28: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 29: Precision = 0.929, Recall = 0.969, F1 = 0.949
# Row 30: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 31: Precision = 0.547, Recall = 0.626, F1 = 0.587
# Row 32: Precision = -0.009, Recall = 0.023, F1 = 0.010
# Row 33: Precision = 0.885, Recall = 0.893, F1 = 0.889
# Row 34: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 35: Precision = 0.775, Recall = 0.625, F1 = 0.698
# Row 36: Precision = 0.215, Recall = 0.162, F1 = 0.190
# Row 37: Precision = 0.589, Recall = 0.704, F1 = 0.646
# Row 38: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 39: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 40: Precision = 0.411, Recall = 0.318, F1 = 0.365
# Row 41: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 42: Precision = 0.546, Recall = 0.611, F1 = 0.579
# Row 43: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 44: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 45: Precision = 0.926, Recall = 0.821, F1 = 0.872
# Row 46: Precision = 0.463, Recall = 0.567, F1 = 0.515
# Row 47: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 48: Precision = 0.665, Recall = 0.676, F1 = 0.672
# Row 49: Precision = -0.023, Recall = -0.382, F1 = -0.233
# Row 50: Precision = 0.142, Recall = -0.127, F1 = -0.005
# Row 51: Precision = 1.000, Recall = 1.000, F1 = 1.000
# Row 52: Precision = 1.000, Recall = 1.000, F1 = 1.000
#
# === Average BERTScores ===
# Average Precision: 0.7499
# Average Recall:    0.7240
# Average F1:        0.7354
